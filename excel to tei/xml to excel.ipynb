# %%
import xml.etree.ElementTree as et

xtree = et.parse('output.xml')
xroot = xtree.getroot()

# %%
people = [person for person in xroot.iter('{http://www.tei-c.org/ns/1.0}person')]

# %%
import pandas as pd
import numpy as np

# %%
altNames = set()
for p in people:
    # persName alt names
    n = p.findall('{http://www.tei-c.org/ns/1.0}persName')
    for _n in n:
        if _n.attrib.get('subtype') is not None:
            _k = 'name-' + _n.attrib.get('type') + '-' + _n.attrib.get('subtype')
            altNames.add(_k)
        elif _n.attrib.get('type') is not None:
            _k = 'name-'+_n.attrib.get('type')
            altNames.add(_k)
print(altNames)
# Out:
# {'name-standardEn', 'name-altName-书名', 'name-altName-别号', 'name-altName-pen name', 'name-altName-alias', 'name-altName-real name', 'name-altName-pinyin', 'name-altName-title', 'name-altName-别署', 'name-altName-字', 'name-altName-别名', 'name-altName-原名'}

# %%
idnos = set()
for p in people:
    n = p.findall('{http://www.tei-c.org/ns/1.0}idno')
    for _n in n:
        if _n.attrib.get('type') is not None:
            _k = 'id-'+_n.attrib.get('type')
            idnos.add(_k)
print(idnos)
# Out:
# {'id-VIAF', 'id-legacy1', 'id-NUS_lib'}

# %%
traits = set()
for p in people:
    n = p. findall('{http://www.tei-c.org/ns/1.0}trait')
    for m in n:
        k = m.find('{http://www.tei-c.org/ns/1.0}label')
        if k is not None:
            traits.add(k.text)
print(traits)
# Out:
# {'Ancestral Home 祖籍地', 'Dialect Group 方言群', 'Faith 信仰', 'Related Organization', 'Work Organization'}

# %%
bibls = set()
for p in people:
    n = p.findall('{http://www.tei-c.org/ns/1.0}listBibl')
    for m in n:
        k = m.attrib.get('type')
        bibls.add(k)
print(bibls)
# Out:
# {'sourcesOn', 'worksBy', 'imagesOf'}

# %%
cols = ['id', 'name-zh-hans', 'name-zh-hant'] + list(altNames) + list(idnos) + ['birth-date', 'birth-place-zh', 'birth-place-en', 'birth-ref', 'death-date', 'death-ref', 'floruit-date', 'floruit-place', 'floruit-ref', 'sex', ] + list(traits) + list(bibls) + ['occupation']
print(cols)
# Out:
# ['id', 'name-zh-hans', 'name-zh-hant', 'name-standardEn', 'name-altName-书名', 'name-altName-别号', 'name-altName-pen name', 'name-altName-alias', 'name-altName-real name', 'name-altName-pinyin', 'name-altName-title', 'name-altName-别署', 'name-altName-字', 'name-altName-别名', 'name-altName-原名', 'id-VIAF', 'id-legacy1', 'id-NUS_lib', 'birth-date', 'birth-place-zh', 'birth-place-en', 'birth-ref', 'death-date', 'death-ref', 'floruit-date', 'floruit-place', 'floruit-ref', 'sex', 'Ancestral Home 祖籍地', 'Dialect Group 方言群', 'Faith 信仰', 'Related Organization', 'Work Organization', 'sourcesOn', 'worksBy', 'imagesOf', 'occupation']

# %%
ori_data = {c:[] for c in cols}
print(ori_data)
# Out:
# {'id': [], 'name-zh-hans': [], 'name-zh-hant': [], 'name-standardEn': [], 'name-altName-书名': [], 'name-altName-别号': [], 'name-altName-pen name': [], 'name-altName-alias': [], 'name-altName-real name': [], 'name-altName-pinyin': [], 'name-altName-title': [], 'name-altName-别署': [], 'name-altName-字': [], 'name-altName-别名': [], 'name-altName-原名': [], 'id-VIAF': [], 'id-legacy1': [], 'id-NUS_lib': [], 'birth-date': [], 'birth-place-zh': [], 'birth-place-en': [], 'birth-ref': [], 'death-date': [], 'death-ref': [], 'floruit-date': [], 'floruit-place': [], 'floruit-ref': [], 'sex': [], 'Ancestral Home 祖籍地': [], 'Dialect Group 方言群': [], 'Faith 信仰': [], 'Related Organization': [], 'Work Organization': [], 'sourcesOn': [], 'worksBy': [], 'imagesOf': [], 'occupation': []}

# %%
delimiter = ';'
df = pd.DataFrame()

dict_index = 0

for p in people:
    person = {}
    
    for key in ori_data:
        ori_data[key].append(None)
    
    # id
    _id = p.attrib.get('{http://www.w3.org/XML/1998/namespace}id')
    ori_data['id'][dict_index] = _id
    
    # persName with lang
    n = p.find('{http://www.tei-c.org/ns/1.0}persName[@{http://www.w3.org/XML/1998/namespace}lang="zh-Hans"]')
    _name_zh_Hans = n.text if n is not None else None
    ori_data['name-zh-hans'][dict_index] = _name_zh_Hans
    
    n = p.find('{http://www.tei-c.org/ns/1.0}persName[@{http://www.w3.org/XML/1998/namespace}lang="zh-Hant"]')
    _name_zh_Hant = n.text if n is not None else None
    ori_data['name-zh-hant'][dict_index] = _name_zh_Hant
    
    # persName alt names
    n = p.findall('{http://www.tei-c.org/ns/1.0}persName')
    for _n in n:
        if _n.attrib.get('subtype') is not None:
            _k = 'name-' + _n.attrib.get('type') + '-' + _n.attrib.get('subtype')
            if _k in person:
                person[_k] += delimiter + _n.text
            else:
                person[_k] = _n.text
        elif _n.attrib.get('type') is not None:
            _k = 'name-'+_n.attrib.get('type')
            if _k in person:
                person[_k] += delimiter + _n.text
            else:
                person[_k] = _n.text
    for person_key in person:
        ori_data[person_key][dict_index] = person[person_key]
    person.clear()
        
    # idno
    n = p.findall('{http://www.tei-c.org/ns/1.0}idno')
    for _n in n:
        if _n.attrib.get('type') is not None:
            _k = 'id-'+_n.attrib.get('type')
            person[_k] = _n.text
    for person_key in person:
        ori_data[person_key][dict_index] = person[person_key]
    person.clear()
    
    # birth
    n = p.find('{http://www.tei-c.org/ns/1.0}birth')
    m = n.find('{http://www.tei-c.org/ns/1.0}date')
    _birth_date = m.text if m is not None else None
    ori_data['birth-date'][dict_index] = _birth_date
    m = n.find('{http://www.tei-c.org/ns/1.0}placeName[@{http://www.w3.org/XML/1998/namespace}lang="zh"]')
    _birth_placeName_zh = m.text if m is not None else None
    ori_data['birth-place-zh'][dict_index] = _birth_placeName_zh
    m = n.find('{http://www.tei-c.org/ns/1.0}placeName[@{http://www.w3.org/XML/1998/namespace}lang="en"]')
    _birth_placeName_en = m.text if m is not None else None
    ori_data['birth-place-en'][dict_index] = _birth_placeName_en
    m = n.findall('{http://www.tei-c.org/ns/1.0}ref')
    _birth_ref = delimiter.join([_m.text if _m.text is not None else '' for _m in m] if m is not None else [])
    ori_data['birth-ref'][dict_index] = _birth_ref
    
    # death
    n = p.find('{http://www.tei-c.org/ns/1.0}death')
    m = n.find('{http://www.tei-c.org/ns/1.0}date')
    _death_date = m.text if m is not None else None
    ori_data['death-date'][dict_index] = _death_date
    m = n.findall('{http://www.tei-c.org/ns/1.0}ref')
    _death_ref = delimiter.join([_m.text if _m.text is not None else '' for _m in m] if m is not None else [])
    ori_data['death-ref'][dict_index] = _death_ref
    
    # floruit
    n = p.find('{http://www.tei-c.org/ns/1.0}floruit')
    m = n.find('{http://www.tei-c.org/ns/1.0}date')
    _floruit_date = m.text if m is not None else None
    ori_data['floruit-date'][dict_index] = _floruit_date
    m = n.find('{http://www.tei-c.org/ns/1.0}placeName')
    _floruit_placeName = m.text if m is not None else None
    ori_data['floruit-place'][dict_index] = _floruit_placeName
    m = n.findall('{http://www.tei-c.org/ns/1.0}ref')
    _floruit_ref = delimiter.join([_m.text if _m.text is not None else '' for _m in m] if m is not None else [])
    ori_data['floruit-ref'][dict_index] = _floruit_ref
    
    # sex
    n = p.find('{http://www.tei-c.org/ns/1.0}sex')
    _sex = n.text if n is not None else None
    ori_data['sex'][dict_index] = _sex
    
    # trait
    n = p. findall('{http://www.tei-c.org/ns/1.0}trait')
    for m in n:
        k = m. find('{http://www.tei-c.org/ns/1.0}label')
        d = m. find('{http://www.tei-c.org/ns/1.0}desc')
        if k is not None and k.text in person:
            person[k.text] += (delimiter + d.text) if d.text is not None else ''
        elif k is not None:
            person[k.text] = d.text if d.text is not None else ''
    for person_key in person:
        ori_data[person_key][dict_index] = person[person_key]
    person.clear()
    
    # list bibl
    n = p.findall('{http://www.tei-c.org/ns/1.0}listBibl')
    for m in n:
        k = m.attrib.get('type')
        l = []
        for d in m.findall('{http://www.tei-c.org/ns/1.0}bibl'):
            if d.text is None:
                continue
            l.append(d.text)
        v = delimiter.join(l)
        # hack for imagesOf, as it's always empty for now
        if k == 'imagesOf':
            v = ''
        ori_data[k][dict_index] = v

    # occupation
    l = []
    n = p.findall('{http://www.tei-c.org/ns/1.0}occupation')
    for m in n:
        if m.text is None:
            continue
        l.append(m.text)
    v = delimiter.join(l)
    ori_data['occupation'][dict_index] = v
        
    dict_index += 1

# %%
df = pd.DataFrame(ori_data)
df
# Out:
#           id name-zh-hans name-zh-hant name-standardEn name-altName-书名  \
# 0    s000000          李大傻         None     Lee Dai Soh            None
# 1    s000001          孙中山         None     Sun Yat-sen            None
# 2    s000002          蔡志民         None            None            None
# 3    s000003          伍伯胜         None            None            None
# 4    s000004          伍连德         None     Wu Lien Teh            None
# 5    s000005          陈梦桃         None            None            None
# 6    s000006          徐统雄         None            None            None
# 7    s000007          陈瑞麟         None            None            None
# 8    s000008          杨缵文         None   Yeo Chan Boon            None
# 9    s000009          林忠国         None            None            None
# 10   s000010          林义顺         None    Lim Nee Soon              其华
# 11   s000011          陈烈三         None            None            None
# 12   s000012          符和谦         None            None            None
# 761            None                  None               None
# 762            None                  None               None
# 763            None                  None               None
# 764            None                  None               None
# 765            None                  None               None
# 766            None                  None               None
# 767            None                  None               None
# 768            None                  None               None
# 769            None                  None               None
# 770            None                  None               None
# 771            None                  None               None
# 772            None                  None               None
# 773            None                  None               None
# 774            None                  None               None
# 775            None                  None               None
# 776            None                  None               None
# 777            None                  None               None
# 778            None                  None               None
# 779            None                  None               None
# 780            None                  None               None
# 781            None                  None               None
# 782            None                  None               None
# 783            None                  None               None
#
#     name-altName-real name name-altName-pinyin  ... sex  \
# 0                     None            Li Dasha  ...   1
# 1                     None       Sun Zhongshan  ...   1
# 2                     None          Cai Zhimin  ...   1
# 3                     None          Wu Bosheng  ...   1
# 4                     None           Wu Liande  ...   1
# 5                     None        Chen Mengtao  ...   1
# 6                     None        Xu Tongxiong  ...   1
# 7                     None         Chen Ruilin  ...   1
# 8                     None        Yang Zuanwen  ...   1
# 9                     None        Lin Zhongguo  ...   1
# 10                    None          Lin Yishun  ...   1
# 11                    None         Chen Liesan  ...   1
# 12                    None           Fu Heqian  ...   1
# 13                    None       Lin Yao xiang  ...   1
# 14                    None        Zhang Yongfu  ...   1
# 15                    None            Hu Yuzhi  ...   1
# 16                    None       Chi Chuanying  ...   1
# 17                    None         Chen Yueshu  ...   1
# 18                    None            Tu Kaiyu  ...   1
# 19                    None         Ma Huixiang  ...   1
# 20                    None        Li Guangqian  ...   1
# 21                    None           Li Yurong  ...   1
# 22                    None          Li Chengyi  ...   1
# 23                    None         Li Chengwei  ...   1
# 24                    None           Liu Mudan  ...   1
# 25                    None        Zhou Xianrui  ...   1
# 26                    None        Huang Yihuan  ...   1
# 27                    None          Gao Yunlan  ...   1
# 28                    None           He Baoren  ...   1
# 29                    None         Chen Senmao  ...   1
# ..                     ...                 ...  ...  ..
# 754                   None         Liang Yunqi  ...   1
# 755                   None       Lei Liangrong  ...   1
# 756                   None       Zhuang Caixun  ...   1
# 757                   None       Qiu Zongcheng  ...   1
# 758                   None           Yang Fuhe  ...   1
# 759                   None          Chen Yunji  ...   1
# 760                   None         Lin Minglun  ...   1
# 761                   None            Yongqing  ...   1
# 762                   None           Zeng Jize  ...   1
# 763                   None         Xue Fucheng  ...   1
# 764                   None          Liu Qingyu  ...   1
# 765                   None         Liu Qingkun  ...   1
# 766                   None           He Yanmao  ...   1
# 767                   None           Yu Kunhuo  ...   1
# 768                   None         Wu Qingteng  ...   1
# 769                   None        Liu Rongfeng  ...   1
# 770                   None         Wang Zheliu  ...   1
# 771                   None        Chen Yaliang  ...   1
# 772                   None          Chen Ruoyu  ...   1
# 773                   None       Zhou Runxiang  ...   1
# 774                   None          Gan Qingsi  ...   1
# 775                   None        Huang Zhixin  ...   1
# 776                   None        Ying Kunyang  ...   1
# 777                   None           Yu Yuying  ...   1
# 778                   None        Chen Guochao  ...   1
# 779                   None        Ding Honghai  ...   1
# 780                   None        Wang Shuidou  ...   1
# 770                                                暂无/               暂无/
# 771                                                暂无/               暂无/
# 772          广东省潮安县/Chao'an County, Guangdong Province         潮/Teochew
# 773  福建省海澄县（今属龙海县）/Haicheng County, Fujian Province...         闽/Hokkien
# 774  福建省海澄县（今属龙海县）/Haicheng County, Fujian Province...         闽/Hokkien
# 775             福建省同安县/Tong'an County, Fujian Province         闽/Hokkien
# 776                                                暂无/               暂无/
# 777                                                暂无/               暂无/
# 778                                                暂无/         闽/Hokkien
# 779                                                暂无/         闽/Hokkien
# 780                    福建省东山/Dongshan, Fujian Province         闽/Hokkien
# 781                      福建省金门/Jinmen, Fujian Province         闽/Hokkien
# 782                   广东台山/Taishan, Guangdong Province          粤/Canton
# 783                      福建省金门/Jinmen, Fujian Province         闽/Hokkien
#
#     Faith 信仰                               Related Organization  \
# 0                                                   东安会馆;广惠肇碧山亭
# 1                                                          None
# 2                                    南洋客属总会;丰永大公会;丰顺会馆;星洲鞋业商会董事
# 3                                                          None
# 4                                                          None
# 5                                                          应新学堂
# 6                                                          None
# 7                                                         星华筹赈会
# 8                                                          None
# 9                                                          None
# 10                                            乡务局;南洋华侨中学;潮州八邑会馆
# 11                                                         None
# 12                                             符氏社;南洋华侨筹賑祖国难民总会
# 13                                                         None
# 14                                   中国同盟会新加坡分会;中国国民党新加坡支部;中兴日报
# 15                                                        抗日后援会
# 16                                         三江会馆;福利委员会;温州会馆;侨南公学
# 17                                       新加坡上海书局;温州会馆;三江会馆;中国银行
# 18                                                         None
# 19                                                         None
# 20                                                         None
# 21                                                         None
# 22                                                         None
# 23                                                         None
# 24                             南安会馆;南洋华侨筹赈祖国难民总会;新加坡中华总商会;建筑商公会
# 25                                                         None
# 26            民族抗日先锋队;南洋华侨筹赈祖国难民总会;福建会馆;闽侨会馆;中华总商会;南洋华侨中学;弥陀...
# 27                                                    南洋华侨回国慰问团
# 28                                                         None
# 29                                                         None
# ..       ...                                                ...
# 754                                                        None
# 755                                                        None
# 756                                                        None
# 757                                                        None
# 758                                                        None
# 759                                                     保赤宫陈氏宗祠
# 760                    星华公学;南壁同乡会;银河音乐会;星洲琼崖林氏公会;令金埠琼州会馆;令金振强学校
# 761                                                        None
# 762                                                        None
# 763                                                        None
# 764                                                       英语雄辨会
# 765                                                     海峡华人体育会
# 766                                                       英语雄辩会
# 767                                                        None
# 768                                               醉花林俱乐部;潮侨社团组织
# 769                                                        None
# 770                                                        None
# 771                                                        None
# 772                                                        None
# 773                                             中华商务总会;天福宫;道南学校
# 774                                 新加坡中华总商会;新加坡南洋华侨中学;南洋工商补习学校
# 775                                                        None
# 776                     义勇军;海峡英籍华人公会;新加坡华人女子学校;圣彼得传道堂;新加坡主教管区协会
# 777                                                        None
# 778                                                         庆德会
# 779                                                        None
# 780                                                        None
# 781                                                        None
# 782                                                        None
# 783                                                        None
#
#                                Work Organization sourcesOn  \
# 0                                     马来亚电台;丽的呼声
# 1                                           None
# 2                                        志和行、志祥行
# 3                                      中国驻新加坡领事馆
# 4                                           None
# 5                                           None
# 6                                           None
# 7                                    松发园;陈奇珍号杂货店
# 8                                           None
# 9                                           None
# 10   华商银行;联东保险有限公司;乌鲁班兰树胶有限公司;同济医院;联合火锯有限公司;华侨银行
# 11                                          None
# 12                                          None
# 13                                          None
# 14                       《图南日报》;汕头市;中央银行汕头分行;侨务局
# 15                   《南洋商报》;《生活周刊》;《世界知识》;《南侨日报》
# 16                               三民皮箱皮鞋公司;三民企业公司
# 17                                        侨兴有限公司
# 18                                   暨南学堂;南洋华侨中学
# 19                                          None
# 20                                          None
# 21                                          None
# 22                                          None
# 23                                          None
# 24                                          新业公司
# 25                                          None
# 26              振兴公司;协隆源公司;亚洲人寿保险有限公司;亚洲联合企业有限公司
# 27        厦门商报;漳潮日报;厦门中华中学;马来亚麻坡中华中学;钜元贸易公司;南侨日报
# 28                                          None
# 29                                          None
# ..                                           ...       ...
# 754                                         None
# 755                              nan;丰益东;和益号;新泉发
# 756                                         None
# 757                                         None
# 758                                        庄庆利公司
# 759                                         允吉公司
# 760       育英小学;令金埠永发昌树胶园;南洋华侨中学;中正学校;华义中学;实能工艺中学
# 761                                         永清公司
# 762                                         None
# 763                                         None
# 764                                         None
# 765                                         None
# 766                                         渣打银行
# 767                                         None
# 768                                         None
# 769                                         None
# 770                                         None
# 771                                         None
# 772                                         None
# 773                                    协容茂轮船有限公司
# 774                               协荣茂轮船有限公司;华侨银行
# 775                                         None
# 776                   新加坡土地局;沃恩律师馆;布雷德尔兄弟与马休斯律师馆
# 777                                         None
# 778                                     陈金声公司丰兴号
# 779                                         None
# 780                                         None
# 781                                      新成发板柴商业
# 782                                         None
# 783                                         None
#
#                                                worksBy imagesOf  occupation
# 0                                                                      讲古艺人
# 1
# 2                                                                        商人
# 3                                                                       外交官
# 4
# 5
# 6
# 7                                                                    农场主;商人
# 8
# 9                                                                        商人
# 10                                                                      企业家
# 11                                                                       艺人
# 12                                                                       商人
# 13
# 14                                                                      革命家
# 15                                                                       报人
# 16                                                                       商人
# 17                                                                       商人
# 18                                                《华侨》                教育工作者
# 19
# 20
# 21                                                                      企业家
# 22
# 23
# 24                                                                       商人
# 25
# 26                                                                       商人
# 27   《前夜》;《夕影》;《大岗》;《没太阳的早晨》;《翻脸》;《汉奸往见上帝记》;《救亡戏剧的“...                作家;报人
# 28
# 29
# ..                                                 ...      ...         ...
# 754
# 755                                                                     总司事
# 756
# 757
# 758                                                                      商人
# 759                                                                    取佣代理
# 760                                                                   教育工作者
# 761                                                                      船主
# 762
# 763
# 764                                                                      秘书
# 765                                                                      秘书
# 766                                                                      职员
# 767
# 768                                                                      商人
# 769
# 770
# 771
# 772
# 773                                                                      商人
# 774                                                                    华社领袖
# 775
# 776                                                               公务员;律师馆职员
# 777
# 778                                                                      商人
# 779
# 780
# 781                                                              商业;儿童教育;素封
# 782
# 783
#
# [784 rows x 37 columns]

# %%
df.to_excel("xml-to-excel.xlsx")
